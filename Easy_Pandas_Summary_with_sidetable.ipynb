# %% [markdown]
# <a href="https://colab.research.google.com/github/Sirinth2u/BasicPython/blob/main/Easy_Pandas_Summary_with_sidetable.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns # for dataset

# %%
! pip install sidetable
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
titanic = sns.load_dataset('titanic')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic['survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: survived, dtype: int64

# %%
import sidetable

# %%
titanic.stb.freq(['sex'], style = True)
# Out:
# <style type="text/css">
# </style>
# <table id="T_86175_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >sex</th>
#       <th class="col_heading level0 col1" >count</th>
#       <th class="col_heading level0 col2" >percent</th>
#       <th class="col_heading level0 col3" >cumulative_count</th>
#       <th class="col_heading level0 col4" >cumulative_percent</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_86175_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_86175_row0_col0" class="data row0 col0" >male</td>
#       <td id="T_86175_row0_col1" class="data row0 col1" >577</td>
#       <td id="T_86175_row0_col2" class="data row0 col2" >64.76%</td>
#       <td id="T_86175_row0_col3" class="data row0 col3" >577</td>
#       <td id="T_86175_row0_col4" class="data row0 col4" >64.76%</td>
#     </tr>
#     <tr>
# ...

# %%
titanic.stb.freq(['sex','pclass','embarked'], thresh = 80)
# Out:
#       sex  pclass embarked  count    percent  cumulative_count  \
# 0    male     3.0        S    265  29.808774               265
# 1    male     2.0        S     97  10.911136               362
# 2  female     3.0        S     88   9.898763               450
# 3    male     1.0        S     79   8.886389               529
# 4  female     2.0        S     67   7.536558               596
# 5  female     1.0        S     48   5.399325               644
# 6    male     3.0        C     43   4.836895               687
# 7  others  others   others    202  22.722160               889
#
#    cumulative_percent
# 0           29.808774
# 1           40.719910
# 2           50.618673
# 3           59.505062
# 4           67.041620
# 5           72.440945
# 6           77.277840
# 7          100.000000

# %%
titanic.stb.freq(['class'], value = 'fare')
# Out:
#     class        fare    percent  cumulative_fare  cumulative_percent
# 0   First  18177.4125  63.349288       18177.4125           63.349288
# 1   Third   6714.6951  23.401084       24892.1076           86.750371
# 2  Second   3801.8417  13.249629       28693.9493          100.000000

# %%
titanic.stb.freq(['embarked','pclass'], thresh= 80)
# Out:
#   embarked  pclass  count    percent  cumulative_count  cumulative_percent
# 0        S     3.0    353  39.707537               353           39.707537
# 1        S     2.0    164  18.447694               517           58.155231
# 2        S     1.0    127  14.285714               644           72.440945
# 3   others  others    245  27.559055               889          100.000000

# %%
titanic.stb.missing()
# Out:
#              missing  total    percent
# deck             688    891  77.216611
# age              177    891  19.865320
# embarked           2    891   0.224467
# embark_town        2    891   0.224467
# survived           0    891   0.000000
# pclass             0    891   0.000000
# sex                0    891   0.000000
# sibsp              0    891   0.000000
# parch              0    891   0.000000
# fare               0    891   0.000000
# class              0    891   0.000000
# who                0    891   0.000000
# adult_male         0    891   0.000000
# alive              0    891   0.000000
# alone              0    891   0.000000
